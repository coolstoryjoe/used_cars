# %%
from models import load_obj
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)
df = pd.DataFrame(load_obj('Master_File_v1'))
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-6372ddb95d6a> in <module>
#       2 import pandas as pd
#       3 pd.set_option("display.max_rows", None, "display.max_columns", None)
# ----> 4 df = pd.DataFrame(load_obj('Master_File_v1'))
#       5 df
#
# ~/Coding/Python/used_cars/models.py in load_obj(name)
#      44
#      45 def load_obj(name):
# ---> 46     with open(str(os.path.join(os.getcwd(), 'pickle_jar', str(name + '.pkl'))), 'rb') as f:
#      47         return pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/josepholeynik/Coding/Python/used_cars/pickle_jar/Master_File_v1.pkl'

# %%
from models import load_obj
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)
df = pd.DataFrame(load_obj('Acura_to_FIAT_TRAIL_DF'))
df
# Out:
#  Turbo    3
# 38     25 City / 36 Highway    2 wheel drive - rear    4-Cylinder Turbo    3
# 39     25 City / 36 Highway    2 wheel drive - rear    4-Cylinder Turbo    3
# 40     25 City / 36 Highway    2 wheel drive - rear    4-Cylinder Turbo    3
# 41     25 City / 36 Highway    2 wheel drive - rear    4-Cylinder Turbo    3
# 42     26 City / 35 Highway    2 wheel drive - rear    4-Cylinder Turbo    3
# 43     25 City / 36 Highway    2 wheel drive - rear    4-Cylinder Turbo    3
# 44     25 City / 36 Highway    2 wheel drive - rear    4-Cylinder Turbo    3
# 45     25 City / 36 Highway    2 wheel drive - rear    4-Cylinder Turbo    3
# 46     26 City / 35 Highway    2 wheel drive - rear    4-Cylinder Turbo    3
# 47     25 City / 36 Highway    2 wheel drive - rear    4-Cylinder Turbo    3
# 48     26 City / 35 Highway    2 wheel drive - rear    4-Cylinder Turbo    3
# 49     26 City / 35 Highway    2 wheel drive - rear    4-Cylinder Turbo    3
# ...

# %%
if df is not None:
    print('uy')
# Out:
# uy
